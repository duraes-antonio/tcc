# %%
# Importação de Libs
from PIL import Image
import sys
import os

# %tensorflow_version 1.15
import tensorflow as tf

sys.path.append('utils')
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# Definição de caminhos
path_codigo = "/content/drive/My Drive/tcc_src"
path_modelos = f"{path_codigo}/src/modelos"
path_deeplab = f"{path_codigo}/src/modelos/deeplab"

# %%
os.environ['PYTHONPATH'] += f':{path_modelos}/:{path_codigo}/src/modelos/slim/'

# Caso ocorra um erro com a dependência tf-slim, basta executar:
# !pip install git+https://github.com/google-research/tf-slim
# Out:
# ...
#   Cloning https://github.com/google-research/tf-slim to /tmp/pip-req-build-j6g3f6h4
#   Running command git clone -q https://github.com/google-research/tf-slim /tmp/pip-req-build-j6g3f6h4
# ...
#   Created wheel for tf-slim: filename=tf_slim-1.2.0-cp36-none-any.whl size=360911 sha256=25c776f88fa8198d987b86cad383279002c1922d72bc16ffc1a6d367d4ef1c1e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6yymksl/wheels/bb/98/dc/eba6500d756d16f6ff371b39ed733d26cec1b0b0085e1cb0df
# Successfully built tf-slim
# ...

# %%
# Informe que o diretório raiz é o Caminho do código da DeepLab
os.chdir(path_modelos)
# !export PYTHONPATH=$PYTHONPATH:pwd:pwd/slim

# %%
# Execute o modelo de teste
# !python deeplab/model_test.py

# %%
# Informe que o diretório raiz é a pasta 'datasets' dentro de 'deeplab'
os.chdir(f'{path_deeplab}/datasets')
# !python convert_rgb_to_index.py

# %%
# Informe que o diretório raiz é a pasta 'datasets' dentro de 'deeplab'
os.chdir(f'{path_deeplab}/datasets')
# !python build_pqr_data.py
# Out:
# WARNING:tensorflow:From build_pqr_data.py:317: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From build_pqr_data.py:129: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From build_pqr_data.py:131: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-10-16 04:50:31.081790: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-16 04:50:31.099116: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-16 04:50:31.100069: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# ...

# %%
# Informe que o diretório raiz é a pasta 'datasets' dentro de 'deeplab'
os.chdir(path_modelos)
# !sh train-pqr.sh
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/tcc_src/src/modelos/deeplab/core/conv2d_ws.py:40: The name tf.layers.Layer is deprecated. Please use tf.compat.v1.layers.Layer instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/tcc_src/src/modelos/deeplab/train.py:453: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/tcc_src/src/modelos/deeplab/train.py:263: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %%
# Informe que o diretório raiz é a pasta 'datasets' dentro de 'deeplab'
os.chdir(path_modelos)
# !sh vis-pqr.sh

# %%
# Informe que o diretório raiz é a pasta 'datasets' dentro de 'deeplab'
os.chdir(path_modelos)
# !sh eval-pqr.sh
